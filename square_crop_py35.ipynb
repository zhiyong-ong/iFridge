# %%
import Image
im = Image.open("C:/Users/zhiyong/Desktop/School Work/IMAGES/20170121_151254.jpg")
width, height = im.size   # Get dimensions
new_width = 50
new_height = 50
left = (width - new_width)/2
top = (height - new_height)/2
right = (width + new_width)/2
bottom = (height + new_height)/2

im.crop((left, top, right, bottom))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-0d25da672188> in <module>()
# ----> 1 import Image
#       2 im = Image.open("C:/Users/zhiyong/Desktop/School Work/IMAGES/20170121_151254.jpg")
#       3 width, height = im.size   # Get dimensions
#       4 new_width = 50
#       5 new_height = 50
#
# ImportError: No module named 'Image'

# %%
# import the necessary packages
import cv2
import os
i = 1
for filename in os.listdir("C:/Users/zhiyong/Desktop/School Work/IMAGES/coke"):
    if filename.endswith(".jpg") or filename.endswith(".py"): 
        # load the image and show it
        image = cv2.imread("C:/Users/zhiyong/Desktop/School Work/IMAGES/coke/" + filename)

        (h, w) = image.shape[:2]
        print(h)
        print(w)
        center = (w / 2, h / 2)
        new_width = 800
        new_height = 800

        print(center[0])
        offset = -1
        
        for _a in range(3):
            vert_offset = offset * 350
            offsetHor = -1
            for _ in range(3):
                hor_offset = offsetHor * 350
                left = int(center[0] - new_width + hor_offset)
                right = int(center[0] + new_width + hor_offset)
                bottom = int(center[1] - new_height + vert_offset)
                top = int(center[1] + new_height + vert_offset)

                cropped = image[bottom:top, left:right]

                cv2.imwrite("Coke" + str(i) + ".png", cropped)
                i +=1
                offsetHor += 1
            offset += 1

    else:
        continue
# Out:
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0

# %%
# import the necessary packages
import cv2
import os
i = 1
for filename in os.listdir("C:/Users/zhiyong/Desktop/School Work/IMAGES/coke"):
    if filename.endswith(".jpg") or filename.endswith(".py"): 
        # load the image and show it
        image = cv2.imread("C:/Users/zhiyong/Desktop/School Work/IMAGES/coke/" + filename)

        (h, w) = image.shape[:2]
        print(h)
        print(w)
        center = (w / 2, h / 2)
        new_width = 1000
        new_height = 1000

        print(center[0])

        left = int(center[0] - new_width)
        right = int(center[0] + new_width)
        bottom = int(center[1] - new_height)
        top = int(center[1] + new_height)

        cropped = image[bottom:top, left:right]

        cv2.imwrite("Coke" + str(i) + ".jpeg", cropped)
        i +=1


    else:
        continue
# Out:
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
# 4032
# 3024
# 1512.0
